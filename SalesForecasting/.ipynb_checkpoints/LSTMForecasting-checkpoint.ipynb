# %% [markdown]
# # Importing Data

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
def load_data():
    return pd.read_csv('train.csv')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

import keras
from keras.layers import Dense
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam # - Works
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras.layers import LSTM
from sklearn.model_selection import KFold, cross_val_score, train_test_split

import pickle

# %% [markdown]
# # Load Data

# %%
model_df = pd.read_csv('model_df.csv')

# %%
model_df.shape
# Out:
# (47, 15)

# %%
model_df.head()
# Out:
#          date   sales  sales_diff     lag_1     lag_2     lag_3     lag_4  \
# 0  2014-02-01  529117      3130.0   19380.0 -186036.0   36056.0  -33320.0
# 1  2014-03-01  704301    175184.0    3130.0   19380.0 -186036.0   36056.0
# 2  2014-04-01  788914     84613.0  175184.0    3130.0   19380.0 -186036.0
# 3  2014-05-01  882877     93963.0   84613.0  175184.0    3130.0   19380.0
# 4  2014-06-01  906842     23965.0   93963.0   84613.0  175184.0    3130.0
#
#       lag_5     lag_6    lag_7    lag_8    lag_9   lag_10    lag_11    lag_12
# 0  -76854.0  -89161.0  60325.0  32355.0  80968.0  64892.0  157965.0    4513.0
# 1  -33320.0  -76854.0 -89161.0  60325.0  32355.0  80968.0   64892.0  157965.0
# 2   36056.0  -33320.0 -76854.0 -89161.0  60325.0  32355.0   80968.0   64892.0
# 3 -186036.0   36056.0 -33320.0 -76854.0 -89161.0  60325.0   32355.0   80968.0
# 4   19380.0 -186036.0  36056.0 -33320.0 -76854.0 -89161.0   60325.0   32355.0

# %%
model_df[0:-12]
# Out:
#           date    sales  sales_diff     lag_1     lag_2     lag_3     lag_4  \
# 0   2014-02-01   529117      3130.0   19380.0 -186036.0   36056.0  -33320.0
# 1   2014-03-01   704301    175184.0    3130.0   19380.0 -186036.0   36056.0
# 2   2014-04-01   788914     84613.0  175184.0    3130.0   19380.0 -186036.0
# 3   2014-05-01   882877     93963.0   84613.0  175184.0    3130.0   19380.0
# 4   2014-06-01   906842     23965.0   93963.0   84613.0  175184.0    3130.0
# 5   2014-07-01   989010     82168.0   23965.0   93963.0   84613.0  175184.0
# 6   2014-08-01   885596   -103414.0   82168.0   23965.0   93963.0   84613.0
# 7   2014-09-01   785124   -100472.0 -103414.0   82168.0   23965.0   93963.0
# 8   2014-10-01   758883    -26241.0 -100472.0 -103414.0   82168.0   23965.0
# 9   2014-11-01   800783     41900.0  -26241.0 -100472.0 -103414.0   82168.0
# 10  2014-12-01   578048   -222735.0   41900.0  -26241.0 -100472.0 -103414.0
# 11  2015-01-01   552513    -25535.0 -222735.0   41900.0  -26241.0 -100472.0
# 12  2015-02-01   551317     -1196.0  -25535.0 -222735.0   41900.0  -26241.0
# 13  2015-03-01   730951    179634.0   -1196.0  -25535.0 -222735.0   41900.0
# 14  2015-04-01   824467     93516.0  179634.0   -1196.0  -25535.0 -222735.0
# 15  2015-05-01   926902    102435.0   93516.0  179634.0   -1196.0  -25535.0
# 16  2015-06-01   937184     10282.0  102435.0   93516.0  179634.0   -1196.0
# 17  2015-07-01  1037350    100166.0   10282.0  102435.0   93516.0  179634.0
# 43  2017-09-01   935263    -91140.0 -144990.0  106769.0   43938.0   81824.0
# 44  2017-10-01   891160    -44103.0  -91140.0 -144990.0  106769.0   43938.0
# 45  2017-11-01   928837     37677.0  -44103.0  -91140.0 -144990.0  106769.0
# 46  2017-12-01   695170   -233667.0   37677.0  -44103.0  -91140.0 -144990.0
#
#        lag_5     lag_6     lag_7     lag_8     lag_9    lag_10    lag_11  \
# 35 -157224.0  116054.0   33934.0   86780.0  111069.0  175924.0   12518.0
# 36  -84663.0 -157224.0  116054.0   33934.0   86780.0  111069.0  175924.0
# 37  -33194.0  -84663.0 -157224.0  116054.0   33934.0   86780.0  111069.0
# 38   27811.0  -33194.0  -84663.0 -157224.0  116054.0   33934.0   86780.0
# 39 -228037.0   27811.0  -33194.0  -84663.0 -157224.0  116054.0   33934.0
# 40  -46105.0 -228037.0   27811.0  -33194.0  -84663.0 -157224.0  116054.0
# 41    4063.0  -46105.0 -228037.0   27811.0  -33194.0  -84663.0 -157224.0
# 42  201298.0    4063.0  -46105.0 -228037.0   27811.0  -33194.0  -84663.0
# 43  116195.0  201298.0    4063.0  -46105.0 -228037.0   27811.0  -33194.0
# 44   81824.0  116195.0  201298.0    4063.0  -46105.0 -228037.0   27811.0
# 45   43938.0   81824.0  116195.0  201298.0    4063.0  -46105.0 -228037.0
# 46  106769.0   43938.0   81824.0  116195.0  201298.0    4063.0  -46105.0
#
#       lag_12
# 35   -5133.0
# 36   12518.0
# 37  175924.0
# 38  111069.0
# 39   86780.0
# 40   33934.0
# 41  116054.0
# 42 -157224.0
# 43  -84663.0
# 44  -33194.0
# 45   27811.0
# 46 -228037.0

# %% [markdown]
# # Train Test Split

# %%
def tts(data):
    data = data.drop(['sales','date'],axis=1)
    train, test = data[0:-12].values, data[-12:].values #first 35 rows for training, from 35 - 46 index for testing
    
    return train, test

train, test = tts(model_df)

# %%
train.shape
# Out:
# (35, 13)

# %%
test.shape
# Out:
# (12, 13)

# %%
def scale_data(train_set, test_set):
    #apply Min Max Scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_set)
    
    # reshape training set
    train_set = train_set.reshape(train_set.shape[0], train_set.shape[1])
    train_set_scaled = scaler.transform(train_set)
    
    # reshape test set
    test_set = test_set.reshape(test_set.shape[0], test_set.shape[1])
    test_set_scaled = scaler.transform(test_set)
    
    X_train, y_train = train_set_scaled[:, 1:], train_set_scaled[:, 0:1].ravel()
    X_test, y_test = test_set_scaled[:, 1:], test_set_scaled[:, 0:1].ravel()
    
    return X_train, y_train, X_test, y_test, scaler

X_train, y_train, X_test, y_test, scaler_object = scale_data(train, test)

# %%
print(f"""shape of x_train {X_train.shape}
shape of x_test {X_test.shape}
shape of y_train {y_train.shape}
shape of y_test {y_test.shape}""")
# Out:
# shape of x_train (35, 12)
# shape of x_test (12, 12)
# shape of y_train (35,)
# shape of y_test (12,)

# %% [markdown]
# # Modeling Functions

# %%
#unscaled = undo_scaling(predictions, X_test, scaler_object)
def undo_scaling(y_pred, x_test, scaler_obj):  
    #reshape y_pred
    y_pred = y_pred.reshape(y_pred.shape[0], 1, 1)
    
    #rebuild test set for inverse transform
    pred_test_set = []
    for index in range(0,len(y_pred)):
        pred_test_set.append(np.concatenate([y_pred[index],x_test[index]],axis=1))
        
    #reshape pred_test_set
    #as we know we converted the data from 2d-3d time to convert back from 3d-2d
    pred_test_set = np.array(pred_test_set)
    pred_test_set = pred_test_set.reshape(pred_test_set.shape[0], pred_test_set.shape[2])
    
    #inverse transform
    pred_test_set_inverted = scaler_obj.inverse_transform(pred_test_set)
    
    return pred_test_set_inverted

# %%
#original_df = load_original_df()
def load_original_df():
    #load in original dataframe without scaling applied
    original_df = pd.read_csv('train.csv')
    original_df.date = original_df.date.apply(lambda x: str(x)[:-3]) # removing day
    original_df = original_df.groupby('date')['sales'].sum().reset_index()
    original_df.date = pd.to_datetime(original_df.date)
    return original_df

# %%
#unscaled_df = predict_df(unscaled, original_df)
def predict_df(unscaled_predictions, original_df):
    #create dataframe that shows the predicted sales
    result_list = []
    sales_dates = list(original_df[-13:].date)
    act_sales = list(original_df[-13:].sales)
    
    for index in range(0,len(unscaled_predictions)):
        result_dict = {}
        result_dict['pred_value'] = int(unscaled_predictions[index][0] + act_sales[index])
        result_dict['date'] = sales_dates[index+1]
        result_list.append(result_dict)
        
    df_result = pd.DataFrame(result_list)
    
    return df_result

# %%
#get_scores(unscaled_df, original_df, model_name)

model_scores = {}

def get_scores(unscaled_df, original_df, model_name):
    r2 = r2_score(original_df.sales[-12:], unscaled_df.pred_value[-12:])
    print(f"R2 Score: {r2}")

# %%
#plot_results(unscaled_df, original_df, model_name)
def plot_results(results, original_df, model_name):

    fig, ax = plt.subplots(figsize=(15,5))
    sns.lineplot(original_df.date, original_df.sales, data=original_df, ax=ax, 
                 label='Original', color='mediumblue')
    sns.lineplot(results.date, results.pred_value, data=results, ax=ax, 
                 label='Predicted', color='Red')
    
    ax.set(xlabel = "Date",
           ylabel = "Sales",
           title = f"{model_name} Sales Forecasting Prediction")
    
    ax.legend()
    
    sns.despine()
    
    plt.savefig(f'{model_name}_forecast.png')

# %% [markdown]
# # LSTM

# %%
def lstm_model(train_data, test_data):
    
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
   
    model = Sequential()
    model.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2]), 
                   stateful=True))
    model.add(Dense(1))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, 
              shuffle=False)
    predictions = model.predict(X_test,batch_size=1)
    
    original_df = load_original_df()
    unscaled = undo_scaling(predictions, X_test, scaler_object)
    unscaled_df = predict_df(unscaled, original_df)
    
    get_scores(unscaled_df, original_df, 'LSTM')
    
    plot_results(unscaled_df, original_df, 'LSTM')

# %%
lstm_model(train, test)
# Out:
# Epoch 1/200
# 35/35 [==============================] - 21s 1ms/step - loss: 0.1119
# Epoch 2/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0950
# Epoch 3/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0928
# Epoch 4/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0878
# Epoch 5/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0819
# Epoch 6/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0765
# Epoch 7/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0715
# Epoch 8/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0668
# Epoch 9/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0623
# Epoch 10/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0582
# Epoch 11/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0545
# Epoch 12/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0511
# Epoch 13/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0480
# Epoch 14/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0452
# Epoch 15/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0427
# Epoch 16/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0404
# Epoch 17/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0382
# Epoch 18/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0363
# Epoch 19/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 20/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 21/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0312
# Epoch 22/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0297
# Epoch 23/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0283
# Epoch 24/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 25/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0258
# Epoch 26/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0246
# Epoch 27/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 28/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0225
# Epoch 29/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0215
# Epoch 30/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0206
# Epoch 31/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0197
# Epoch 32/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0188
# Epoch 33/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0181
# Epoch 34/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0173
# Epoch 35/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0166
# Epoch 36/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0159
# Epoch 37/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0153
# Epoch 38/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0147
# Epoch 39/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 40/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0135
# Epoch 41/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 42/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0125
# Epoch 43/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0120
# Epoch 44/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0115
# Epoch 45/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0111
# Epoch 46/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0107
# Epoch 47/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 48/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0099
# Epoch 49/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 50/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 51/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 52/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 53/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 54/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0080
# Epoch 55/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0077
# Epoch 56/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0075
# Epoch 57/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0072
# Epoch 58/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0070
# Epoch 59/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 60/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0066
# Epoch 61/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 62/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0062
# Epoch 63/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0060
# Epoch 64/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 65/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0057
# Epoch 66/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0055
# Epoch 67/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0054
# Epoch 68/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0053
# Epoch 69/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0051
# Epoch 70/200
# 35/35 [==============================] - 0s 997us/step - loss: 0.0050
# Epoch 71/200
# 35/35 [==============================] - 0s 968us/step - loss: 0.0049
# Epoch 72/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 73/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0047
# Epoch 74/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0046
# Epoch 75/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0045
# Epoch 76/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 77/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 78/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0042
# Epoch 79/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 80/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0041
# Epoch 81/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 82/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 83/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 84/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0038
# Epoch 85/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 86/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0037
# Epoch 87/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 88/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 89/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 90/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 91/200
# 35/35 [==============================] - 0s 997us/step - loss: 0.0034
# Epoch 92/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 93/200
# 35/35 [==============================] - 0s 997us/step - loss: 0.0033
# Epoch 94/200
# 35/35 [==============================] - 0s 910us/step - loss: 0.0033
# Epoch 95/200
# 35/35 [==============================] - 0s 997us/step - loss: 0.0033
# Epoch 96/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 97/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 98/200
# 35/35 [==============================] - 0s 968us/step - loss: 0.0032
# Epoch 99/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 100/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 101/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 102/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 103/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 104/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 105/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 106/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 107/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 108/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 109/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 110/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 111/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 112/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 113/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 114/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 115/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 116/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 117/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 118/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 119/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 120/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 121/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 122/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 123/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 124/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 125/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 126/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 127/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 128/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 129/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 130/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 131/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 132/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 133/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 134/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 135/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 136/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 137/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 138/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 139/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 140/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 141/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 142/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 143/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 144/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 145/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 146/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 147/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 148/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 149/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 150/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 151/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 152/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 153/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 154/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 155/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 156/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 157/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 158/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 159/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 160/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 161/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 162/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 163/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 164/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 165/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 166/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 167/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 168/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 169/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 170/200
# 35/35 [==============================] - 0s 996us/step - loss: 0.0017
# Epoch 171/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 172/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 173/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 174/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 175/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 176/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 177/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 178/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 179/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 180/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 181/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 182/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 183/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 184/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 185/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 186/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 187/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 188/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 189/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0015
# Epoch 190/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 191/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 192/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 193/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 194/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 195/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 196/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 197/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 198/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 199/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0013
# Epoch 200/200
# 35/35 [==============================] - 0s 1ms/step - loss: 0.0013
# R2 Score: 0.9926398347723582

# %%
pickle.dump(model_scores, open( "model_scores.p", "wb" ) )
